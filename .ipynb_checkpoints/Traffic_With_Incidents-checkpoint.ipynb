# %%
import pandas as pd

# %%
incidents = pd.read_csv("featured_datasets/incidents_with_distances.csv",",")
traffic = pd.read_csv("featured_datasets/featured_traffic_flow.csv",",")

# %%
incidents
# Out:
#       city_name         description cause_of_incident  \
# 0         Braga     queuing traffic               NaN
# 1         Braga     queuing traffic               NaN
# 2         Braga     queuing traffic               NaN
# 3         Braga  stationary traffic               NaN
# 4         Braga  stationary traffic               NaN
# ...         ...                 ...               ...
# 83342     Braga  stationary traffic               NaN
# 83343     Braga  stationary traffic               NaN
# 83344     Braga  stationary traffic               NaN
# 83345     Braga  stationary traffic               NaN
# 83346     Braga        slow traffic               NaN
#
#                                                from_road  \
# 0                                       Quinteiro (N103)
# 1                        Rua Manuel Almeida Passos (N14)
# 2                                  Braga-Circular (N101)
# 3                 Avenida General Norton De Matos (N101)
# ...

# %%
traffic
# Out:
#        road_num             road_name  functional_road_class_desc  \
# 0             1  Avenida da Liberdade  Local High Importance Road
# 1             2       Avenida Central  Local High Importance Road
# 2             3         Rua de Caires       Local Connecting Road
# 3             4             N14 Bosch            Other Major Road
# 4             1  Avenida da Liberdade  Local High Importance Road
# ...         ...                   ...                         ...
# 81595         1  Avenida da Liberdade  Local High Importance Road
# 81596         2       Avenida Central  Local High Importance Road
# 81597         3         Rua de Caires              Secondary Road
# 81598         4             N14 Bosch            Other Major Road
# 81599         4             N14 Bosch            Other Major Road
#
#        Day of year  week_or_not  Hour  Minute  time_rate
# 0               15            1    19       5   1.000000
# 1               15            1    19       5   3.013158
# ...
